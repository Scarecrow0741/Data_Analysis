# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# ## Reindexing

# %%
obj = pd.Series([4.5, 7.2, -5.3, 3.6], index=["d", "b", "a", "c"])
obj
# Out:
# d    4.5
# b    7.2
# a   -5.3
# c    3.6
# dtype: float64

# %%
obj2 = obj.reindex(["a", "b", "c", "d", "e"])
obj2
# Out:
# a   -5.3
# b    7.2
# c    3.6
# d    4.5
# e    NaN
# dtype: float64

# %%
obj3 = pd.Series(["blue", "purple", "yellow"], index=[0, 2, 4])
obj3
# Out:
# 0      blue
# 2    purple
# 4    yellow
# dtype: object

# %%
obj3.reindex(range(6), method="ffill")
# Out:
# 0      blue
# 1      blue
# 2    purple
# 3    purple
# 4    yellow
# 5    yellow
# dtype: object

# %%
frame = pd.DataFrame( np.arange(9) . reshape((3,3)) , index = [ 'a' , 'c' , 'd' ] , columns = ["Ohio", "Texas", "California"])
frame
# Out:
#    Ohio  Texas  California
# a     0      1           2
# c     3      4           5
# d     6      7           8

# %%
frame2 = frame.reindex(index=["a", "b", "c", "d"])
frame2
# Out:
#    Ohio  Texas  California
# a   0.0    1.0         2.0
# b   NaN    NaN         NaN
# c   3.0    4.0         5.0
# d   6.0    7.0         8.0

# %%
states = ["Texas", "Utah", "California"]
frame.reindex( columns = states )
# Out:
#    Texas  Utah  California
# a      1   NaN           2
# c      4   NaN           5
# d      7   NaN           8

# %%
frame.reindex(states, axis="columns") #does the same the thing as the prev one
# Out:
#    Texas  Utah  California
# a      1   NaN           2
# c      4   NaN           5
# d      7   NaN           8

# %% [markdown]
# ### reindex function arguments
#
# | Argument | Description |
# | :--- | :--- |
# | `labels` | New sequence to use as an index. Can be Index instance or any other sequence-like Python data structure. An Index will be used exactly as is without any copying. |
# | `index` | Use the passed sequence as the new index labels. |
# | `columns` | Use the passed sequence as the new column labels. |
# | `axis` | The axis to reindex, whether "index" (rows) or "columns". The default is "index". You can alternately do `reindex(index=new_labels)` or `reindex(columns=new_labels)`. |
# | `method` | Interpolation (fill) method; `"ffill"` fills forward, while `"bfill"` fills backward. |
# | `fill_value` | Substitute value to use when introducing missing data by reindexing. Use `fill_value="missing"` (the default behavior) when you want absent labels to have null values in the result. |
# | `limit` | When forward filling or backfilling, the maximum size gap (in number of elements) to fill. |
# | `tolerance` | When forward filling or backfilling, the maximum size gap (in absolute numeric distance) to fill for inexact matches. |
# | `level` | Match simple Index on level of MultiIndex; otherwise select subset of. |
# | `copy` | If `True`, always copy underlying data even if the new index is equivalent to the old index; if `False`, do not copy the data when the indexes are equivalent. |

# %% [markdown]
# ## Dropping Entries from an Axis

# %%
obj = pd.Series(np.arange(5.), index=["a", "b", "c", "d", "e"])
obj2 = obj.drop("a")
obj2
# Out:
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
obj.drop("c")
# Out:
# a    0.0
# b    1.0
# d    3.0
# e    4.0
# dtype: float64

# %%
data = pd.DataFrame(np.arange(16).reshape((4, 4)),
    index=["Ohio", "Colorado", "Utah", "New York"],
    columns=["one", "two", "three", "four"])
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data.drop( index = ["Utah"] )
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# New York   12   13     14    15

# %%
data.drop( columns = ["two"])
# Out:
#           one  three  four
# Ohio        0      2     3
# Colorado    4      6     7
# Utah        8     10    11
# New York   12     14    15

# %%
data.drop( "two" , axis = 1 )
# Out:
#           one  three  four
# Ohio        0      2     3
# Colorado    4      6     7
# Utah        8     10    11
# New York   12     14    15

# %% [markdown]
# ## Indexing, Selection, and Filtering

# %%
obj = pd.Series(np.arange(4.), index=["a", "b", "c", "d"])
obj
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# dtype: float64

# %%
obj["b"]
# Out:
# np.float64(1.0)

# %%
obj[1]
# Out:
# C:\Users\Rasif Rohan\AppData\Local\Temp\ipykernel_5904\2469632899.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   obj[1]
# np.float64(1.0)

# %%
obj[2:4]
# Out:
# c    2.0
# d    3.0
# dtype: float64

# %%
obj[obj < 2]
# Out:
# a    0.0
# b    1.0
# dtype: float64

# %%
obj.loc[["a", "b", "c"]] #loc operator indexes exclusively with labels
# Out:
# a    0.0
# b    1.0
# c    2.0
# dtype: float64

# %%
obj.iloc[[1, 2, 3]] # iloc operator indexes exclusively with integers
# Out:
# b    1.0
# c    2.0
# d    3.0
# dtype: float64

# %%
obj2 = pd.Series([1, 2, 3], index=["a", "b", "c"])
obj2
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
obj2.loc["b":"c"]
# Out:
# b    2
# c    3
# dtype: int64

# %%
obj2.loc["b" : "c" ] = 5 
obj2
# Out:
# a    1
# b    5
# c    5
# dtype: int64

# %%
data = pd.DataFrame(np.arange(16).reshape((4, 4)),
    index=["Ohio", "Colorado", "Utah", "New York"],
    columns=["one", "two", "three", "four"])
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data[["three"  , "four"]]
# Out:
#           three  four
# Ohio          2     3
# Colorado      6     7
# Utah         10    11
# New York     14    15

# %%
data[:2]
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7

# %%
data[data["three"] > 5]
# Out:
#           one  two  three  four
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %% [markdown]
# ### Selection on DataFrame with loc and iloc

# %%
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data.loc["Colorado"]
# Out:
# one      4
# two      5
# three    6
# four     7
# Name: Colorado, dtype: int64

# %%
data.loc[["Colorado" ,"Utah"]]
# Out:
#           one  two  three  four
# Colorado    4    5      6     7
# Utah        8    9     10    11

# %%
data.loc["Colorado" ,["two" , "three"]]
# Out:
# two      5
# three    6
# Name: Colorado, dtype: int64

# %%
data.iloc[2]
# Out:
# one       8
# two       9
# three    10
# four     11
# Name: Utah, dtype: int64

# %%
data.iloc[[2,1]]
# Out:
#           one  two  three  four
# Utah        8    9     10    11
# Colorado    4    5      6     7

# %%
data.iloc[[2,1], [3,1]]
# Out:
#           four  two
# Utah        11    9
# Colorado     7    5

# %%
data.loc[:"Utah" , :"two"]
# Out:
#           one  two
# Ohio        0    1
# Colorado    4    5
# Utah        8    9

# %%
data.iloc[:, :3] [ data["three"]>5 ]
# Out:
#           one  two  three
# Colorado    4    5      6
# Utah        8    9     10
# New York   12   13     14

# %% [markdown]
# ### Indexing options with DataFrame
#
# | Type | Notes |
# | :--- | :--- |
# | `df[column]` | Select single column or sequence of columns from the DataFrame; special case conveniences: Boolean array (filter rows), slice (slice rows), or Boolean DataFrame (set values based on some criterion) |
# | `df.loc[rows]` | Select single row or subset of rows from the DataFrame by label |
# | `df.loc[:, cols]` | Select single column or subset of columns by label |
# | `df.loc[rows, cols]` | Select both row(s) and column(s) by label |
# | `df.iloc[rows]` | Select single row or subset of rows from the DataFrame by integer position |
# | `df.iloc[:, cols]` | Select single column or subset of columns by integer position |
# | `df.iloc[rows, cols]` | Select both row(s) and column(s) by integer position |
# | `df.at[row, col]` | Select a single scalar value by row and column label |
# | `df.iat[row, col]` | Select a single scalar value by row and column position (integers) |
# | `reindex` method | Select either rows or columns by labels |

# %% [markdown]
# ## Arithmetic and Data Alignment

# %%
s1 = pd.Series([7.3, -2.5, 3.4, 1.5], index=["a", "c", "d", "e"])
s2 = pd.Series([-2.1, 3.6, -1.5, 4, 3.1],index=["a", "c", "e", "f", "g"])

# %%
s1
# Out:
# a    7.3
# c   -2.5
# d    3.4
# e    1.5
# dtype: float64

# %%
s2
# Out:
# a   -2.1
# c    3.6
# e   -1.5
# f    4.0
# g    3.1
# dtype: float64

# %%
s1+s2
# Out:
# a    5.2
# c    1.1
# d    NaN
# e    0.0
# f    NaN
# g    NaN
# dtype: float64

# %%
df1 = pd.DataFrame(np.arange(9.).reshape((3, 3)), columns=list("bcd"),
    index=["Ohio", "Texas", "Colorado"])
df2 = pd.DataFrame(np.arange(12.).reshape((4, 3)), columns=list("bde"),
    index=["Utah", "Ohio", "Texas", "Oregon"])

# %%
df1
# Out:
#             b    c    d
# Ohio      0.0  1.0  2.0
# Texas     3.0  4.0  5.0
# Colorado  6.0  7.0  8.0

# %%
df2
# Out:
#           b     d     e
# Utah    0.0   1.0   2.0
# Ohio    3.0   4.0   5.0
# Texas   6.0   7.0   8.0
# Oregon  9.0  10.0  11.0

# %%
df1+df2
# Out:
#             b   c     d   e
# Colorado  NaN NaN   NaN NaN
# Ohio      3.0 NaN   6.0 NaN
# Oregon    NaN NaN   NaN NaN
# Texas     9.0 NaN  12.0 NaN
# Utah      NaN NaN   NaN NaN

# %% [markdown]
# ### Arithmetic methods with fill values

# %%
df1 = pd.DataFrame( np.arange(12).reshape((3,4)) , columns = list("abcd"))
df2 = pd.DataFrame(np.arange(20.).reshape((4, 5)),columns = list("abcde"))

# %%
df1
# Out:
#    a  b   c   d
# 0  0  1   2   3
# 1  4  5   6   7
# 2  8  9  10  11

# %%
df2
# Out:
#       a     b     c     d     e
# 0   0.0   1.0   2.0   3.0   4.0
# 1   5.0   6.0   7.0   8.0   9.0
# 2  10.0  11.0  12.0  13.0  14.0
# 3  15.0  16.0  17.0  18.0  19.0

# %%
df1+df2
# Out:
#       a     b     c     d   e
# 0   0.0   2.0   4.0   6.0 NaN
# 1   9.0  11.0  13.0  15.0 NaN
# 2  18.0  20.0  22.0  24.0 NaN
# 3   NaN   NaN   NaN   NaN NaN

# %%
df1.add(df2, fill_value = 0 )
# Out:
#       a     b     c     d     e
# 0   0.0   2.0   4.0   6.0   4.0
# 1   9.0  11.0  13.0  15.0   9.0
# 2  18.0  20.0  22.0  24.0  14.0
# 3  15.0  16.0  17.0  18.0  19.0

# %%
df1.rdiv(1)
# Out:
#        a         b         c         d
# 0    inf  1.000000  0.500000  0.333333
# 1  0.250  0.200000  0.166667  0.142857
# 2  0.125  0.111111  0.100000  0.090909

# %% [markdown]
# ### Flexible arithmetic methods
#
# | Method | Description |
# | :--- | :--- |
# | `add`, `radd` | Methods for addition (+) |
# | `sub`, `rsub` | Methods for subtraction (-) |
# | `div`, `rdiv` | Methods for division (/) |
# | `floordiv`, `rfloordiv` | Methods for floor division (//) |
# | `mul`, `rmul` | Methods for multiplication (*) |
# | `pow`, `rpow` | Methods for exponentiation (**) |

# %% [markdown]
# ### Operations between DataFrame and Series

# %%
frame = pd.DataFrame(np.arange(12.).reshape((4, 3)),
    columns=list("bde"),
    index=["Utah", "Ohio", "Texas", "Oregon"])
frame
# Out:
#           b     d     e
# Utah    0.0   1.0   2.0
# Ohio    3.0   4.0   5.0
# Texas   6.0   7.0   8.0
# Oregon  9.0  10.0  11.0

# %%
series = frame.iloc[0]
series
# Out:
# b    0.0
# d    1.0
# e    2.0
# Name: Utah, dtype: float64

# %%
frame - series
# Out:
#           b    d    e
# Utah    0.0  0.0  0.0
# Ohio    3.0  3.0  3.0
# Texas   6.0  6.0  6.0
# Oregon  9.0  9.0  9.0

# %%
series2= pd.Series(np.arange(3), index = list("bef"))
series2
# Out:
# b    0
# e    1
# f    2
# dtype: int64

# %%
frame + series2
# Out:
#           b   d     e   f
# Utah    0.0 NaN   3.0 NaN
# Ohio    3.0 NaN   6.0 NaN
# Texas   6.0 NaN   9.0 NaN
# Oregon  9.0 NaN  12.0 NaN

# %%
series3 = frame["d"]
series3
# Out:
# Utah       1.0
# Ohio       4.0
# Texas      7.0
# Oregon    10.0
# Name: d, dtype: float64

# %%
frame.sub( series3 , axis = "index")
# Out:
#           b    d    e
# Utah   -1.0  0.0  1.0
# Ohio   -1.0  0.0  1.0
# Texas  -1.0  0.0  1.0
# Oregon -1.0  0.0  1.0

# %% [markdown]
# ### Function Application and Mapping

# %%
frame = pd.DataFrame(np.random.standard_normal((4, 3)),
    columns=list("bde"),
    index=["Utah", "Ohio", "Texas", "Oregon"])
frame
# Out:
#                b         d         e
# Utah   -0.119733 -0.463236  0.199447
# Ohio    1.590679  0.241981 -1.024506
# Texas   0.848164 -0.332480 -0.719993
# Oregon -0.331236 -1.094223  0.045054

# %%
np.abs(frame)
# Out:
#                b         d         e
# Utah    0.119733  0.463236  0.199447
# Ohio    1.590679  0.241981  1.024506
# Texas   0.848164  0.332480  0.719993
# Oregon  0.331236  1.094223  0.045054

# %%
def f1(x):
    return x.max() - x.min()

frame.apply(f1)
# Out:
# b    1.921915
# d    1.336204
# e    1.223952
# dtype: float64

# %%
frame.apply(f1, axis = "columns")
# Out:
# Utah      0.662682
# Ohio      2.615185
# Texas     1.568157
# Oregon    1.139278
# dtype: float64

# %%
def f2(x):
    return pd.Series([x.min(), x.max()], index=["min", "max"])

frame.apply(f2)
# Out:
#             b         d         e
# min -0.331236 -1.094223 -1.024506
# max  1.590679  0.241981  0.199447

# %%
def my_format(x):
    return f"{x:.2f}"

frame.applymap(my_format)
# Out:
# C:\Users\Rasif Rohan\AppData\Local\Temp\ipykernel_5904\2705683181.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   frame.applymap(my_format)
#             b      d      e
# Utah    -0.12  -0.46   0.20
# Ohio     1.59   0.24  -1.02
# Texas    0.85  -0.33  -0.72
# Oregon  -0.33  -1.09   0.05

# %% [markdown]
# ### Sorting and Ranking

# %%
obj = pd.Series( np.arange(4) , index = list("dabc"))
obj
# Out:
# d    0
# a    1
# b    2
# c    3
# dtype: int64

# %%
obj.sort_index()
# Out:
# a    1
# b    2
# c    3
# d    0
# dtype: int64

# %%
frame = pd.DataFrame(np.arange(8).reshape((2, 4)),
    index=["three", "one"],
    columns=["d", "a", "b", "c"])
frame
# Out:
#        d  a  b  c
# three  0  1  2  3
# one    4  5  6  7

# %%
frame.sort_index()
# Out:
#        d  a  b  c
# one    4  5  6  7
# three  0  1  2  3

# %%
frame.sort_index(axis = "columns")
# Out:
#        a  b  c  d
# three  1  2  3  0
# one    5  6  7  4

# %%
frame.sort_index( axis = "columns" , ascending = False) # will sort in a descending order
# Out:
#        d  c  b  a
# three  0  3  2  1
# one    4  7  6  5

# %%
obj = pd.Series([4, 7, -3, 2])
obj
# Out:
# 0    4
# 1    7
# 2   -3
# 3    2
# dtype: int64

# %%
obj.sort_values() #sorting by the values
# Out:
# 2   -3
# 3    2
# 0    4
# 1    7
# dtype: int64

# %%
obj = pd.Series([4, np.nan, 7, np.nan, -3, 2])
obj
# Out:
# 0    4.0
# 1    NaN
# 2    7.0
# 3    NaN
# 4   -3.0
# 5    2.0
# dtype: float64

# %%
obj.sort_values() #nan values will appear at the bottom
# Out:
# 4   -3.0
# 5    2.0
# 0    4.0
# 2    7.0
# 1    NaN
# 3    NaN
# dtype: float64

# %%
obj.sort_values(na_position = "first") #puts the nan values first
# Out:
# 1    NaN
# 3    NaN
# 4   -3.0
# 5    2.0
# 0    4.0
# 2    7.0
# dtype: float64

# %%
frame = pd.DataFrame({"b": [4, 7, -3, 2], "a": [0, 1, 0, 1]})
frame
# Out:
#    b  a
# 0  4  0
# 1  7  1
# 2 -3  0
# 3  2  1

# %%
frame.sort_values("b")
# Out:
#    b  a
# 2 -3  0
# 3  2  1
# 0  4  0
# 1  7  1

# %%
frame.sort_values(["a","b"])
# Out:
#    b  a
# 2 -3  0
# 0  4  0
# 3  2  1
# 1  7  1

# %%
obj = pd.Series([7, -5, 7, 4, 2, 0, 4])
obj
# Out:
# 0    7
# 1   -5
# 2    7
# 3    4
# 4    2
# 5    0
# 6    4
# dtype: int64

# %%
obj.rank() # basically saying the rank of the value in that index . if the value is repeated then its average is put in there
# Out:
# 0    6.5
# 1    1.0
# 2    6.5
# 3    4.5
# 4    3.0
# 5    2.0
# 6    4.5
# dtype: float64

# %%
obj.rank(method = "first") #ccording to the order in which they’re observed in the data
# Out:
# 0    6.0
# 1    1.0
# 2    7.0
# 3    4.0
# 4    3.0
# 5    2.0
# 6    5.0
# dtype: float64

# %%
obj.rank(ascending = False)
# Out:
# 0    1.5
# 1    7.0
# 2    1.5
# 3    3.5
# 4    5.0
# 5    6.0
# 6    3.5
# dtype: float64

# %%
frame = pd.DataFrame({"b": [4.3, 7, -3, 2], "a": [0, 1, 0, 1],"c": [-2, 5, 8, -2.5]})
frame
# Out:
#      b  a    c
# 0  4.3  0 -2.0
# 1  7.0  1  5.0
# 2 -3.0  0  8.0
# 3  2.0  1 -2.5

# %%
frame.rank(axis= "columns")
# Out:
#      b    a    c
# 0  3.0  2.0  1.0
# 1  3.0  1.0  2.0
# 2  1.0  2.0  3.0
# 3  3.0  2.0  1.0

# %% [markdown]
# ### Tie-breaking methods with rank
#
# | Method | Description |
# | :--- | :--- |
# | `"average"` | Default: assign the average rank to each entry in the equal group |
# | `"min"` | Use the minimum rank for the whole group |
# | `"max"` | Use the maximum rank for the whole group |
# | `"first"` | Assign ranks in the order the values appear in the data |
# | `"dense"` | Like `method="min"`, but ranks always increase by 1 between groups rather than the number of equal elements in a group |

# %% [markdown]
# ## Summarizing and Computing Descriptive Statistics

# %%
df = pd.DataFrame([[1.4, np.nan], [7.1, -4.5],
    [np.nan, np.nan], [0.75, -1.3]],
    index=["a", "b", "c", "d"],
    columns=["one", "two"])
df
# Out:
#     one  two
# a  1.40  NaN
# b  7.10 -4.5
# c   NaN  NaN
# d  0.75 -1.3

# %%
df.sum() #returns a Series containing column sums
# Out:
# one    9.25
# two   -5.80
# dtype: float64

# %%
df.sum(axis="index", skipna=False)
# Out:
# one   NaN
# two   NaN
# dtype: float64

# %%
df.mean(axis = "columns")
# Out:
# a    1.400
# b    1.300
# c      NaN
# d   -0.275
# dtype: float64

# %%
df.idxmax() # gives the index of the max element
# Out:
# one    b
# two    d
# dtype: object

# %%
df.describe()
# Out:
#             one       two
# count  3.000000  2.000000
# mean   3.083333 -2.900000
# std    3.493685  2.262742
# min    0.750000 -4.500000
# 25%    1.075000 -3.700000
# 50%    1.400000 -2.900000
# 75%    4.250000 -2.100000
# max    7.100000 -1.300000

# %%
obj = pd.Series(["a", "a", "b", "c"] * 4)
obj
# Out:
# 0     a
# 1     a
# 2     b
# 3     c
# 4     a
# 5     a
# 6     b
# 7     c
# 8     a
# 9     a
# 10    b
# 11    c
# 12    a
# 13    a
# 14    b
# 15    c
# dtype: object

# %%
obj.describe()
# Out:
# count     16
# unique     3
# top        a
# freq       8
# dtype: object

# %% [markdown]
# ### Descriptive and summary statistics
#
# | Method | Description |
# | :--- | :--- |
# | `count` | Number of non-NA values |
# | `describe` | Compute set of summary statistics |
# | `min`, `max` | Compute minimum and maximum values |
# | `argmin`, `argmax` | Compute index locations (integers) at which minimum or maximum value is obtained, respectively; not available on DataFrame objects |
# | `idxmin`, `idxmax` | Compute index labels at which minimum or maximum value is obtained, respectively |
# | `quantile` | Compute sample quantile ranging from 0 to 1 (default: 0.5) |
# | `sum` | Sum of values |
# | `mean` | Mean of values |
# | `median` | Arithmetic median (50% quantile) of values |
# | `mad` | Mean absolute deviation from mean value |
# | `prod` | Product of all values |
# | `var` | Sample variance of values |
# | `std` | Sample standard deviation of values |
# | `skew` | Sample skewness (third moment) of values |
# | `kurt` | Sample kurtosis (fourth moment) of values |
# | `cumsum` | Cumulative sum of values |
# | `cummin`, `cummax` | Cumulative minimum or maximum of values, respectively |
# | `cumprod` | Cumulative product of values |
# | `diff` | Compute first arithmetic difference (useful for time series) |
# | `pct_change` | Compute percent changes |

# %% [markdown]
# ### Correlation and Covariance

# %%
price = pd.read_pickle("../examples/yahoo_price.pkl")
volume = pd.read_pickle("../examples/yahoo_volume.pkl")

# %%
returns = price.pct_change()
returns.tail()
# Out:
#                 AAPL      GOOG       IBM      MSFT
# Date
# 2016-10-17 -0.000680  0.001837  0.002072 -0.003483
# 2016-10-18 -0.000681  0.019616 -0.026168  0.007690
# 2016-10-19 -0.002979  0.007846  0.003583 -0.002255
# 2016-10-20 -0.000512 -0.005652  0.001719 -0.004867
# 2016-10-21 -0.003930  0.003011 -0.012474  0.042096

# %%
returns["MSFT"].corr( returns["IBM"] )
# Out:
# np.float64(0.4997636114415114)

# %%
returns["MSFT"].cov( returns["IBM"] )
# Out:
# np.float64(8.870655479703546e-05)

# %%
returns.corr()
# Out:
#           AAPL      GOOG       IBM      MSFT
# AAPL  1.000000  0.407919  0.386817  0.389695
# GOOG  0.407919  1.000000  0.405099  0.465919
# IBM   0.386817  0.405099  1.000000  0.499764
# MSFT  0.389695  0.465919  0.499764  1.000000

# %%
returns.cov()
# Out:
#           AAPL      GOOG       IBM      MSFT
# AAPL  0.000277  0.000107  0.000078  0.000095
# GOOG  0.000107  0.000251  0.000078  0.000108
# IBM   0.000078  0.000078  0.000146  0.000089
# MSFT  0.000095  0.000108  0.000089  0.000215

# %%
returns.corrwith(returns["IBM"])
# Out:
# AAPL    0.386817
# GOOG    0.405099
# IBM     1.000000
# MSFT    0.499764
# dtype: float64

# %%
returns.corrwith(volume)
# Out:
# AAPL   -0.075565
# GOOG   -0.007067
# IBM    -0.204849
# MSFT   -0.092950
# dtype: float64

# %% [markdown]
# ### Unique Values, Value Counts, and Membership

# %%
obj = pd.Series(["c", "a", "d", "a", "a", "b", "b", "c", "c"])
obj
# Out:
# 0    c
# 1    a
# 2    d
# 3    a
# 4    a
# 5    b
# 6    b
# 7    c
# 8    c
# dtype: object

# %%
obj.unique()
# Out:
# array(['c', 'a', 'd', 'b'], dtype=object)

# %%
obj.value_counts()
# Out:
# c    3
# a    3
# b    2
# d    1
# Name: count, dtype: int64

# %%
obj.isin(["b","c"])
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
to_match = pd.Series(["c", "a", "b", "b", "c", "a"])
unique_vals = pd.Series(["c", "b", "a"])
pd.Index(unique_vals).get_indexer(to_match)
# Out:
# array([0, 2, 1, 1, 0, 2])

# %% [markdown]
# ### Unique, value counts, and set membership methods
#
# | Method | Description |
# | :--- | :--- |
# | `isin` | Compute a Boolean array indicating whether each Series or DataFrame value is contained in the passed sequence of values |
# | `get_indexer` | Compute integer indices for each value in an array into another array of distinct values; helpful for data alignment and join-type operations |
# | `unique` | Compute an array of unique values in a Series, returned in the order observed |
# | `value_counts` | Return a Series containing unique values as its index and frequencies as its values, ordered count in descending order |

# %%
data = pd.DataFrame({"a": [1, 1, 1, 2, 2], "b": [0, 0, 1, 0, 0]})
data
# Out:
#    a  b
# 0  1  0
# 1  1  0
# 2  1  1
# 3  2  0
# 4  2  0

# %%
data.value_counts() #calculates the occurence of each row
# Out:
# a  b
# 1  0    2
# 2  0    2
# 1  1    1
# Name: count, dtype: int64

# %%
data = pd.DataFrame({"Qu1": [1, 3, 4, 3, 4],
    "Qu2": [2, 3, 1, 2, 3],
    "Qu3": [1, 5, 2, 4, 4]})
data
# Out:
#    Qu1  Qu2  Qu3
# 0    1    2    1
# 1    3    3    5
# 2    4    1    2
# 3    3    2    4
# 4    4    3    4

# %%
data["Qu1"].value_counts().sort_values()
# Out:
# Qu1
# 1    1
# 3    2
# 4    2
# Name: count, dtype: int64

# %%
data.apply(pd.value_counts).fillna(0) # index become the unique value and the occurences in each column is shown
# Out:
# C:\Users\Rasif Rohan\AppData\Local\Temp\ipykernel_5904\2493099384.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   data.apply(pd.value_counts).fillna(0)
#    Qu1  Qu2  Qu3
# 1  1.0  1.0  1.0
# 2  0.0  2.0  1.0
# 3  2.0  2.0  0.0
# 4  2.0  0.0  2.0
# 5  0.0  0.0  1.0
